# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("spotify_songs.csv")
pd.set_option("display.max_rows", None)

# %%
other_data = pd.read_csv("tracks_features.csv")

# %%
data["year"] = data["track_album_release_date"].str[:4]
year_counts = data["year"].value_counts().sort_index()


print(year_counts)
# Out:
# year
# 1957       2
# 1958       1
# 1960       4
# 1961       1
# 1962       2
# 1963       5
# 1964       9
# 1965      12
# 1966      19
# 1967      41
# 1968      23
# 1969      56
# 1970      82
# 1971      71
# 1972      74
# 1973     104
# 1974      80
# 1975     108
# 1976     133
# 1977     100
# 1978     130
# 1979      84
# 1980      97
# 1981      87
# 1982      94
# 1983     118
# 1984     140
# 1985     144
# 1986     121
# 1987     183
# 1988     193
# 1989     129
# 1990     171
# 1991     209
# 1992     186
# 1993     224
# 1994     237
# 1995     219
# 1996     250
# 1997     253
# 1998     283
# 1999     278
# 2000     250
# 2001     312
# 2002     259
# 2003     353
# 2004     385
# 2005     508
# 2006     445
# 2007     470
# 2008     622
# 2009     473
# 2010     615
# 2011     604
# 2012     786
# 2013     956
# 2014    1524
# 2015    1779
# 2016    2127
# 2017    2430
# 2018    3312
# 2019    9081
# 2020     785
# Name: count, dtype: int64

# %%
year_counts.plot(kind="bar")
# Out:
# <Axes: xlabel='year'>
